# %% [markdown]
# <a href="https://colab.research.google.com/github/evelyn12309/murray-dermott-action/blob/main/Codigo_1_astrodinamica.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = 0
y = 0
x1 = -4.150
y1 = 0
x2 = 0
y2 = -5.170
# Jupiter's orbit parameters
a_jup = 5.20
e_jup = 0.048
t_jup = np.linspace(0, 2*np.pi, 1000)

# Asteroid's orbit parameters
a_ast = 3.27
e_ast = 0.262
t_ast = np.linspace(0, 2*np.pi, 1000)

# Calculate positions
x_jup = a_jup * (np.cos(t_jup) - e_jup)
y_jup = a_jup *  np.sqrt(1 - e_jup**2) * np.sin(t_jup)


x_ast = a_ast * (np.cos(t_ast) - e_ast)
y_ast = a_ast * np.sqrt(1 - e_ast**2) * np.sin(t_ast)

# Plot orbits
plt.plot(x, y, 'y*')
plt.plot(x_jup, y_jup, 'c', label='Jupiter')
plt.plot(x_ast, y_ast, 'r',  label='Asteroid')
plt.plot(x1, y1, 'ro')
plt.plot(x2, y2, 'co')

# Add labels and legend
plt.xlabel('Distance (AU)')
plt.ylabel('Distance (AU)')
plt.title('Jupiter and Asteroid Orbits')
plt.legend(loc = 'upper right')

# Display plot
plt.show()
